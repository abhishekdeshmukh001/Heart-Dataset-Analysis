# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
df = pd.read_csv(r'D:\7.30 PM DATA SCIENCE AND AI\DAILY SESSION MATERIALS\SEPT\5th,6th\EDA_project\heart.csv')

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.shape
# Out:
# (303, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# ### 1(A). Univariate Analysis of "target" variable

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df['target'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df['target'].nunique()
# Out:
# 2

# %%
df['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %% [raw]
# # 1 : Heart Disease present --> Patients having heart disease
# # 2: Heart Disease not present --> Patients not having heart disease

# %% [markdown]
# ### 1(B). Visualization of "target" variable

# %%
f = plt.subplots(figsize=(8,6))
ax = sns.countplot(data=df, x='target')

# %% [markdown]
# #### The above plot confirms the findings that -
#
# #####  - There are 165 patients suffering from heart disease, and
#
# #####  - There are 138 patients who do not have any heart disease.

# %%
df.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: target, dtype: int64

# %% [raw]
# # Sex : 1 --> Male
#       : 0 --> Female

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(data=df, x='sex', hue='target')

# %% [markdown]
# ##### The above plot confirms our findings that -
#
# #####  - Out of 96 females - 72 have heart disease and 24 do not have heart disease.
#
# #####  - Similarly, out of 207 males - 93 have heart disease and 114 do not have heart disease.

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(data=df, x='target', hue='sex')

# %%
ax = sns.catplot(x='target', col='sex', data=df, kind='count', height=4)

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(data=df, y='target', hue='sex')

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", data=df, facecolor=(0, 0, 0, 0), linewidth=3, edgecolor=sns.color_palette("dark", 2))
plt.show()

# %%
df['fbs']
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 298    0
# 299    0
# 300    1
# 301    0
# 302    0
# Name: fbs, Length: 303, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(data=df, x='target', hue='fbs')

# %%
df['exang']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 298    1
# 299    0
# 300    0
# 301    1
# 302    0
# Name: exang, Length: 303, dtype: int64

# %%
df['exang'].value_counts()
# Out:
# 0    204
# 1     99
# Name: exang, dtype: int64

# %%
df.groupby('exang')['target'].value_counts()
# Out:
# exang  target
# 0      1         142
#        0          62
# 1      0          76
#        1          23
# Name: target, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(x='target', hue='exang', data=df)

# %% [markdown]
# ### 2. Bivariate Analysis

# %%
correlation = df.corr()

# %%
correlation['target'].sort_values(ascending=False)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %% [markdown]
# ### [1]. Analysis of 'target' and 'cp' variable

# %%
df['cp']
# Out:
# 0      3
# 1      2
# 2      1
# 3      1
# 4      0
#       ..
# 298    0
# 299    3
# 300    0
# 301    0
# 302    1
# Name: cp, Length: 303, dtype: int64

# %%
df['cp'].unique()
# Out:
# array([3, 2, 1, 0], dtype=int64)

# %%
df['cp'].value_counts()
# Out:
# 0    143
# 2     87
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(x='cp', data=df)

# %%
df.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         104
#     1          39
# 1   1          41
#     0           9
# 2   1          69
#     0          18
# 3   1          16
#     0           7
# Name: target, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(x='cp', hue='target', data=df)

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(x='target', hue='cp', data=df)

# %%
ax = sns.catplot(x='target', col='cp', data=df, kind='count', height=4)

# %% [markdown]
# ### [2]. Analysis of 'target' and 'thalach' variable

# %%
df['thalach']
# Out:
# 0      150
# 1      187
# 2      172
# 3      178
# 4      163
#       ...
# 298    123
# 299    132
# 300    141
# 301    115
# 302    174
# Name: thalach, Length: 303, dtype: int64

# %%
df['thalach'].unique()
# Out:
# array([150, 187, 172, 178, 163, 148, 153, 173, 162, 174, 160, 139, 171,
#        144, 158, 114, 151, 161, 179, 137, 157, 123, 152, 168, 140, 188,
#        125, 170, 165, 142, 180, 143, 182, 156, 115, 149, 146, 175, 186,
#        185, 159, 130, 190, 132, 147, 154, 202, 166, 164, 184, 122, 169,
#        138, 111, 145, 194, 131, 133, 155, 167, 192, 121,  96, 126, 105,
#        181, 116, 108, 129, 120, 112, 128, 109, 113,  99, 177, 141, 136,
#         97, 127, 103, 124,  88, 195, 106,  95, 117,  71, 118, 134,  90],
#       dtype=int64)

# %%
df['thalach'].nunique()
# Out:
# 91

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.distplot(x=df['thalach'], bins=10)

# %% [markdown]
# #### We can see that the thalach variable is slightly negatively skewed.

# %%
f, ax = plt.subplots(figsize=(10,6))
plt.grid(True)
x = df['thalach']
x = pd.Series(x, name="Thalach")
ax = sns.distplot(x, bins=10, color='magenta')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.distplot(x=df['thalach'], bins=10, vertical=True)

# %%
f, ax = plt.subplots(figsize=(8,6))
plt.grid(True)
x = df['thalach']
x = pd.Series(x, name='Thalach')
sns.kdeplot(x)
# Out:
# <AxesSubplot:xlabel='Thalach', ylabel='Density'>

# %%
f, ax = plt.subplots(figsize=(8,6))
plt.grid(True)
x = df['thalach']
x = pd.Series(x, name='Thalach')
sns.kdeplot(x, fill=True, color='orange')
# Out:
# <AxesSubplot:xlabel='Thalach', ylabel='Density'>

# %%
f, ax = plt.subplots(figsize=(8,6))
x = df['thalach']
ax = sns.histplot(x, bins=10, kde=False, binwidth=20, fill=False)

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.stripplot(x='target', y='thalach', data=df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='thalach'>

# %% [markdown]
# ####  - We can see that those people suffering from heart disease (target = 1) have relatively higher heart rate (thalach) as compared to people who are not suffering from heart disease (target = 0).

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.stripplot(x='target', y='thalach', data=df, jitter=0.03)
# Out:
# <AxesSubplot:xlabel='target', ylabel='thalach'>

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.boxplot(x='target', y='thalach', data=df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='thalach'>

# %% [markdown]
# ####  - The above boxplot confirms our finding that people suffering from heart disease (target = 1) have relatively higher heart rate (thalach) as compared to people who are not suffering from heart disease (target = 0).

# %% [markdown]
# ### 3. Multivariate Analysis

# %% [markdown]
# ### [1]. Heatmap

# %%
plt.figure(figsize=(16,12))
plt.title('Heatmap of Heart Disease')
hm = sns.heatmap(correlation, annot=True, fmt='.2f')
hm.set_xticklabels(hm.get_xticklabels(), size=12)
hm.set_yticklabels(hm.get_yticklabels(), size=14,rotation=30)
plt.show()

# %% [markdown]
# ### [2]. Pairplots

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
num_v = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'target']
sns.set(font_scale=1.1)
sns.pairplot(df[num_v], kind='scatter')

# %% [markdown]
# ### 2(A). Univariate Analysis of "age" variable

# %%
df['age']
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
df['age'].nunique()
# Out:
# 41

# %%
df['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.distplot(df['age'], bins=10)

# %% [markdown]
# ####  - The age variable distribution is approximately normal.

# %% [markdown]
# ### 2(B). Bivariate Analysis of "age" and "target" variables

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.set_style('white')
sns.stripplot(x='target', y='age', data=df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='age'>

# %% [markdown]
# ####  - We can see that the people suffering from heart disease (target = 1) and people who are not suffering from heart disease (target = 0) have comparable ages.

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.set_style('white')
sns.boxplot(x='target', y='age', data=df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='age'>

# %% [markdown]
# ####  - The mean age of the people who have heart disease is less than the mean age of the people who do not have heart disease.

# %% [markdown]
# ### 3(B). Bivariate Analysis of "chol" and "target" variable

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.set_style('white')
sns.stripplot(x='target', y='chol', data=df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='chol'>

# %% [markdown]
# ####  - We can see that the people suffering from heart disease (target = 1) and people who are not suffering from heart disease (target = 0) have comparable cholestrol values

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.set_style('white')
sns.boxplot(x='target', y='chol', data=df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='chol'>

# %% [markdown]
# ####  - The mean cholestrol values of the people who have heart disease is less than the mean cholestrol values of the people who do not have heart disease.

# %% [markdown]
# ### 4(B). Bivariate Analysis of "age" and "trestbps" variable

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.set_style('white')
sns.scatterplot(x='age', y='trestbps', data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='trestbps'>

# %% [markdown]
# ####  - The above scatter plot shows that there is no correlation between age and trestbps variable.

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.set_style('white')
sns.regplot(x='age', y='trestbps', data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='trestbps'>

# %% [markdown]
# #### -  The above line shows that linear regression model is not good fit to the data.

# %% [markdown]
# ### 5(B). Bivariate Analysis of "age" and "chol" variable

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.scatterplot(x='age', y='chol', data=df)

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.regplot(x='age', y='chol', data=df)

# %% [markdown]
# ####  - The above plot confirms that there is a slighly positive correlation between age and chol variables.

# %% [markdown]
# ### 6(B). Bivariate Analysis of "age" and "oldpeak" variable

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.scatterplot(x='age', y='oldpeak', data=df)

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.regplot(x='age', y='oldpeak', data=df)

# %% [markdown]
# ####  - The above plot confirms that there is a slighly positive correlation between age and oldpeak variables.

# %% [markdown]
# ### 4. Outlier Detection

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df['age']
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
df['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.boxplot(data=df, x='age')

# %% [markdown]
# ####   - The age variable does not contain any outlier.

# %%
df['trestbps']
# Out:
# 0      145
# 1      130
# 2      130
# 3      120
# 4      120
#       ...
# 298    140
# 299    110
# 300    144
# 301    130
# 302    130
# Name: trestbps, Length: 303, dtype: int64

# %%
df['trestbps'].describe()
# Out:
# count    303.000000
# mean     131.623762
# std       17.538143
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.boxplot(data=df, x='trestbps')

# %% [markdown]
# ####  - The trestbps variable contains outliers to the right side.

# %%
df['chol']
# Out:
# 0      233
# 1      250
# 2      204
# 3      236
# 4      354
#       ...
# 298    241
# 299    264
# 300    193
# 301    131
# 302    236
# Name: chol, Length: 303, dtype: int64

# %%
df['chol'].describe()
# Out:
# count    303.000000
# mean     246.264026
# std       51.830751
# min      126.000000
# 25%      211.000000
# 50%      240.000000
# 75%      274.500000
# max      564.000000
# Name: chol, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.boxplot(data=df, x='chol')

# %% [markdown]
# ####  - The chol variable contains outliers to the right side.

# %%
df['thalach']
# Out:
# 0      150
# 1      187
# 2      172
# 3      178
# 4      163
#       ...
# 298    123
# 299    132
# 300    141
# 301    115
# 302    174
# Name: thalach, Length: 303, dtype: int64

# %%
df['thalach'].describe()
# Out:
# count    303.000000
# mean     149.646865
# std       22.905161
# min       71.000000
# 25%      133.500000
# 50%      153.000000
# 75%      166.000000
# max      202.000000
# Name: thalach, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.boxplot(data=df, x='thalach')

# %% [markdown]
# ####  - The thalach variable contains a single outlier to the left side.

# %%
df['oldpeak']
# Out:
# 0      2.3
# 1      3.5
# 2      1.4
# 3      0.8
# 4      0.6
#       ...
# 298    0.2
# 299    1.2
# 300    3.4
# 301    1.2
# 302    0.0
# Name: oldpeak, Length: 303, dtype: float64

# %%
df['oldpeak'].describe()
# Out:
# count    303.000000
# mean       1.039604
# std        1.161075
# min        0.000000
# 25%        0.000000
# 50%        0.800000
# 75%        1.600000
# max        6.200000
# Name: oldpeak, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.boxplot(data=df, x='oldpeak')

# %% [markdown]
# ####  - The oldpeak variable contains outliers to the right side.
